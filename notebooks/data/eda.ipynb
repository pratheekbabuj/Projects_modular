# %%
import pandas as pd

# %%
#  data ingestion reading data


df=pd.read_csv("gemstone.csv")

df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()   ##there are no missing values
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
##segregating numerical and ctegorical colmns

num_col=df.columns[df.dtypes!='O']

# %%
num_col
# Out:
# Index(['id', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')

# %%
cat_col=df.columns[df.dtypes=='O']

# %%
cat_col
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
x=1
for i in num_col:
    sns.barplot(data=df)
    print("\n")
    plt.show()

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.pairplot(data=df)

# %%
df['color'].value_counts()
# Out:
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: color, dtype: int64

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':6}

# %%
df['color']=df['color'].replace(color_map)

# %%
df['color'].head()
# Out:
# 0    3
# 1    6
# 2    4
# 3    4
# 4    4
# Name: color, dtype: int64

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map={"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}

# %%
df["clarity"]
# Out:
# 0          VS2
# 1          SI2
# 2          VS1
# 3          VS1
# 4          VS2
#           ...
# 193568    VVS2
# 193569    VVS2
# 193570     SI1
# 193571     SI1
# 193572     SI2
# Name: clarity, Length: 193573, dtype: object

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={'Fair':1,'Ideal':2,'Good':3,'Very Good':4,'Premium':5}

# %%
df['cut'].replace(cut_map)
# Out:
# 0         5
# 1         4
# 2         2
# 3         2
# 4         5
#          ..
# 193568    2
# 193569    5
# 193570    4
# 193571    4
# 193572    3
# Name: cut, Length: 193573, dtype: int64
